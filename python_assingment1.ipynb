# %% [markdown]
# # DATA EXPLORATION OPERATIONS USING PANDAS

# %% [markdown]
# ## COVID-19 PANDEMIC IN INDIA - STATE WISE RECORD

# %% [markdown]
# #### This dataset is a comprehensive collection of data related to the spread of COVID-19 in India. It captures the number of confirmed cases and deaths in each state and union territory of India from the first reported case in January 2020 to the present day. The dataset was created to provide an understanding of the extent of the COVID-19 pandemic in India.It is updated on a daily basis, and provides essential information that is useful for researchers, policy-makers and citizens. It is an invaluable resource that can be used to understand the dynamics of the virus and to monitor the progress of the virus in each state.

# %%
import pandas as pd

# %% [markdown]
# #### The pandas library imported as pd for the data exploration

# %%
coviddata=pd.read_csv('C://Users//indhu//Downloads//covid.csv')

# %% [markdown]
# #### Using read_csv function, covid.csv dataset is read from the location

# %%
coviddata
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742       1    10612
# 1                             Andhra Pradesh    2339067       3  2324331
# 2                          Arunachal Pradesh      66890       0    66594
# 3                                      Assam     746100       0   738065
# 4                                      Bihar     851379      15   839062
# 5                                 Chandigarh      99348       6    98161
# 6                               Chhattisgarh    1177749       6  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591       0    11587
# 8                                      Delhi    2007188      35  1980632
# 9                                        Goa     259079      26   255040
# 10                                   Gujarat    1277557      41  1266473
# 11                                   Haryana    1056602      43  1045845
# ...

# %% [markdown]
# #### This dataset is downloaded from the kaggle.com

# %%
coviddata.head()
# Out:
#                  state  confirmed  active  passive  deaths     dose1  \
# 0  Andaman and Nicobar      10742       1    10612     129    313284
# 1       Andhra Pradesh    2339067       3  2324331   14733  40643161
# 2    Arunachal Pradesh      66890       0    66594     296    860442
# 3                Assam     746100       0   738065    8035  22549957
# 4                Bihar     851379      15   839062   12302  62944633
#
#       dose2     dose3  precaution_dose  total_doses  population
# 0    320383    236936            53427       991263      426251
# 1  43549055  11703273          6579565    110556756    52883163
# 2    747177     72403            58618      1911760     1528296
# 3  20561790   2082670          1259853     50284713    34586234
# 4  59144387  11983504          3868082    157197041   119461013

# %% [markdown]
# #### The head function is used to view the first 5 observations of the dataset

# %%
coviddata.tail()
# Out:
#             state  confirmed  active  passive  deaths      dose1      dose2  \
# 31      Telengana     841324      71   837142    4111   29607672   29053708
# 32        Tripura     108034       0   107094     940    2658852    2328613
# 33  Uttar Pradesh    2128103      46  2104424   23633  154058287  147716010
# 34    Uttarakhand     449379      28   441600    7751    8180312    7940592
# 35    West Bengal    2118606      58  2097016   21532   67300236   61593452
#
#        dose3  precaution_dose  total_doses  population
# 31  10525975          2702159     77201709    38472769
# 32    271434           204733      5916312     4057847
# 33  35623544          9240735    390639497   228959599
# 34   1346150           867047     20051714    11090425
# 35  10257324          5491943    155962840    97694960

# %% [markdown]
# #### The tail function is used to view the last 5 observations of the dataset

# %%
coviddata.count()
# Out:
# state              36
# confirmed          36
# active             36
# passive            36
# deaths             36
# dose1              36
# dose2              36
# dose3              36
# precaution_dose    36
# total_doses        36
# population         36
# dtype: int64

# %% [markdown]
# #### The count function is used to find the number of observations under each variables of the dataset

# %%
coviddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            36 non-null     object
#  1   confirmed        36 non-null     int64
#  2   active           36 non-null     int64
#  3   passive          36 non-null     int64
#  4   deaths           36 non-null     int64
#  5   dose1            36 non-null     int64
#  6   dose2            36 non-null     int64
#  7   dose3            36 non-null     int64
#  8   precaution_dose  36 non-null     int64
#  9   total_doses      36 non-null     int64
#  10  population       36 non-null     int64
# dtypes: int64(10), object(1)
# memory usage: 3.2+ KB

# %% [markdown]
# #### The info function shows the column names, non-null count and data type of the variables

# %%
coviddata.describe()
# Out:
#           confirmed       active       passive         deaths         dose1  \
# count  3.600000e+01    36.000000  3.600000e+01      36.000000  3.600000e+01
# mean   1.241053e+06    98.666667  1.226213e+06   14741.611111  2.555372e+07
# std    1.833873e+06   305.722844  1.808032e+06   27168.565338  3.234424e+07
# min    1.074200e+04     0.000000  1.061200e+04       4.000000  5.690800e+04
# 25%    1.058625e+05     1.000000  1.048608e+05    1120.750000  1.045166e+06
# 50%    6.127550e+05    10.500000  6.063365e+05    6541.000000  1.777784e+07
# 75%    1.320729e+06    46.750000  1.311100e+06   14292.750000  4.281102e+07
# max    8.136588e+06  1389.000000  7.988008e+06  148416.000000  1.540583e+08
#
#               dose2         dose3  precaution_dose   total_doses    population
# count  3.600000e+01  3.600000e+01     3.600000e+01  3.600000e+01  3.600000e+01
# mean   2.398740e+07  4.286358e+06     1.892749e+06  6.098716e+07  3.712387e+07
# ...

# %% [markdown]
# #### The describe function performs operations like count, mean, standard deviation,minimum value, 25% 50% and 75%of the values and the maximum value in the dataset

# %%
coviddata.shape
# Out:
# (36, 11)

# %% [markdown]
# #### The shape function shows the number of observations and number of variables in the dataset

# %%
coviddata.columns
# Out:
# Index(['state', 'confirmed', 'active', 'passive', 'deaths', 'dose1', 'dose2',
#        'dose3', 'precaution_dose', 'total_doses', 'population'],
#       dtype='object')

# %% [markdown]
# #### The columns function shows the variable names of the dataset

# %%
coviddata.index
# Out:
# RangeIndex(start=0, stop=36, step=1)

# %% [markdown]
# #### The index function shows the starting and ending value of index and number of steps performed between each index value

# %%
coviddata.sort_values(['confirmed'],ascending=[True])
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742       1    10612
# 18                               Lakshadweep      11415       0    11363
# 7   Dadra and Nagar Haveli and Daman and Diu      11591       0    11587
# 17                                    Ladakh      29412       3    29178
# 24                                  Nagaland      35986       0    35204
# 29                                    Sikkim      44319       1    43819
# 2                          Arunachal Pradesh      66890       0    66594
# 22                                 Meghalaya      96783       1    95158
# 5                                 Chandigarh      99348       6    98161
# 32                                   Tripura     108034       0   107094
# 21                                   Manipur     139922       0   137773
# 26                                Puducherry     175508       5   173528
# ...

# %% [markdown]
# #### The sort values function helps to sorting the observations in ascending or desending order

# %%
coviddata['active'].value_counts()
# Out:
# 0       8
# 1       3
# 3       3
# 6       2
# 164     1
# 28      1
# 46      1
# 71      1
# 60      1
# 88      1
# 49      1
# 5       1
# 91      1
# 1389    1
# 4       1
# 1275    1
# 17      1
# 23      1
# 43      1
# 41      1
# 26      1
# 35      1
# 15      1
# 58      1
# Name: active, dtype: int64

# %% [markdown]
# #### The value_count function counts the number of times each value occured under the variables of the dataset

# %%
coviddata.drop_duplicates(inplace=True)

# %% [markdown]
# #### The drop duplicates function removes the duplicate observations available in the dataset

# %%
coviddata
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742       1    10612
# 1                             Andhra Pradesh    2339067       3  2324331
# 2                          Arunachal Pradesh      66890       0    66594
# 3                                      Assam     746100       0   738065
# 4                                      Bihar     851379      15   839062
# 5                                 Chandigarh      99348       6    98161
# 6                               Chhattisgarh    1177749       6  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591       0    11587
# 8                                      Delhi    2007188      35  1980632
# 9                                        Goa     259079      26   255040
# 10                                   Gujarat    1277557      41  1266473
# 11                                   Haryana    1056602      43  1045845
# ...

# %% [markdown]
# #### The dataset after removing the duplicate observations

# %%
coviddata_subset=coviddata[['state','confirmed','active','deaths']]

# %% [markdown]
# #### The subset function helps to select the required variables of the dataset

# %%
coviddata_subset
# Out:
#                                        state  confirmed  active  deaths
# 0                        Andaman and Nicobar      10742       1     129
# 1                             Andhra Pradesh    2339067       3   14733
# 2                          Arunachal Pradesh      66890       0     296
# 3                                      Assam     746100       0    8035
# 4                                      Bihar     851379      15   12302
# 5                                 Chandigarh      99348       6    1181
# 6                               Chhattisgarh    1177749       6   14146
# 7   Dadra and Nagar Haveli and Daman and Diu      11591       0       4
# 8                                      Delhi    2007188      35   26521
# 9                                        Goa     259079      26    4013
# 10                                   Gujarat    1277557      41   11043
# 11                                   Haryana    1056602      43   10714
# ...

# %% [markdown]
# #### This dataset is the subset of the coviddata dataset

# %%
coviddata_row=coviddata[coviddata['active']>50]

# %% [markdown]
# #### The row subset helps to filter the observations of the dataset based on the criteria given

# %%
coviddata_row
# Out:
#           state  confirmed  active  passive  deaths     dose1     dose2  \
# 15    Karnataka    4071893    1275  4030311   40307  50016690  50455767
# 16       Kerala    6828245    1389  6755304   71552  27013745  23791879
# 20  Maharashtra    8136588     164  7988008  148416  84644083  71593498
# 25       Odisha    1336552      91  1327256    9205  31453659  29949756
# 28    Rajasthan    1315455      88  1305714    9653  51103054  46510275
# 30   Tamil Nadu    3594388      60  3556279   38049  56659544  53499923
# 31    Telengana     841324      71   837142    4111  29607672  29053708
# 35  West Bengal    2118606      58  2097016   21532  67300236  61593452
#
#        dose3  precaution_dose  total_doses  population
# 15   5727031          4726542    120928298    66165886
# 16    854595          2215656     57477992    35330888
# 20   5022623          4450343    177678317   120837347
# 25   9995330          3199384     81445474    45429399
# ...

# %% [markdown]
# #### The filtered data after performing row subset operation

# %%
coviddata['doses']=coviddata['dose1']+coviddata['dose2']+coviddata['dose3']

# %% [markdown]
# #### This code is to create a new variable to the coviddata dataset

# %%
coviddata
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742       1    10612
# 1                             Andhra Pradesh    2339067       3  2324331
# 2                          Arunachal Pradesh      66890       0    66594
# 3                                      Assam     746100       0   738065
# 4                                      Bihar     851379      15   839062
# 5                                 Chandigarh      99348       6    98161
# 6                               Chhattisgarh    1177749       6  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591       0    11587
# 8                                      Delhi    2007188      35  1980632
# 9                                        Goa     259079      26   255040
# 10                                   Gujarat    1277557      41  1266473
# 11                                   Haryana    1056602      43  1045845
# ...

# %% [markdown]
# #### The dataset after adding the new variable 'doses'

# %%
coviddata_index=coviddata.set_index("state")

# %% [markdown]
# #### The set index function helps to fix the variable as an index to the dataset

# %%
coviddata_index
# Out:
#                                           confirmed  active  passive  deaths  \
# state
# Andaman and Nicobar                           10742       1    10612     129
# Andhra Pradesh                              2339067       3  2324331   14733
# Arunachal Pradesh                             66890       0    66594     296
# Assam                                        746100       0   738065    8035
# Bihar                                        851379      15   839062   12302
# Chandigarh                                    99348       6    98161    1181
# Chhattisgarh                                1177749       6  1163597   14146
# Dadra and Nagar Haveli and Daman and Diu      11591       0    11587       4
# Delhi                                       2007188      35  1980632   26521
# Goa                                          259079      26   255040    4013
# Gujarat                                     1277557      41  1266473   11043
# ...

# %% [markdown]
# #### The dataset after fixing the variable 'state' as an index to the dataset

# %%
coviddata_index=coviddata_index.reset_index()

# %% [markdown]
# #### The reset index function helps to remove the variable as an index in the dataset

# %%
coviddata_index
# Out:
#                                        state  confirmed  active  passive  \
# 0                        Andaman and Nicobar      10742       1    10612
# 1                             Andhra Pradesh    2339067       3  2324331
# 2                          Arunachal Pradesh      66890       0    66594
# 3                                      Assam     746100       0   738065
# 4                                      Bihar     851379      15   839062
# 5                                 Chandigarh      99348       6    98161
# 6                               Chhattisgarh    1177749       6  1163597
# 7   Dadra and Nagar Haveli and Daman and Diu      11591       0    11587
# 8                                      Delhi    2007188      35  1980632
# 9                                        Goa     259079      26   255040
# 10                                   Gujarat    1277557      41  1266473
# 11                                   Haryana    1056602      43  1045845
# ...

# %% [markdown]
# #### The dataset after removing the variable as an index

# %%
coviddata_loc=coviddata.loc[(coviddata.precaution_dose>1000000)&(coviddata.population>90000000)]

# %% [markdown]
# #### The locate 'loc' function helps to get the required observations by locating the variables with conditions

# %%
coviddata_loc
# Out:
#             state  confirmed  active  passive  deaths      dose1      dose2  \
# 4           Bihar     851379      15   839062   12302   62944633   59144387
# 20    Maharashtra    8136588     164  7988008  148416   84644083   71593498
# 33  Uttar Pradesh    2128103      46  2104424   23633  154058287  147716010
# 35    West Bengal    2118606      58  2097016   21532   67300236   61593452
#
#        dose3  precaution_dose  total_doses  population      doses
# 4   11983504          3868082    157197041   119461013  134072524
# 20   5022623          4450343    177678317   120837347  161260204
# 33  35623544          9240735    390639497   228959599  337397841
# 35  10257324          5491943    155962840    97694960  139151012

# %% [markdown]
# #### The dataset after performing locate function

# %%
coviddata_iloc=coviddata.iloc[1:4,0:5]

# %% [markdown]
# #### The index location 'iloc' function helps to select the specified observations and the variables by giving a range with the starting value and the end value

# %%
coviddata_iloc
# Out:
#                state  confirmed  active  passive  deaths
# 1     Andhra Pradesh    2339067       3  2324331   14733
# 2  Arunachal Pradesh      66890       0    66594     296
# 3              Assam     746100       0   738065    8035

# %% [markdown]
# #### The dataset after performing index location function

# %%
new_coviddata=coviddata.groupby()

# %% [markdown]
# #### The groupby() command is not applicable for this data

# %%
coviddata['passive']=coviddata['passive'].astype('object')

# %% [markdown]
# #### The astype function helps to change the data type of the variables

# %%
coviddata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 0 to 35
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   state            36 non-null     object
#  1   confirmed        36 non-null     int64
#  2   active           36 non-null     int64
#  3   passive          36 non-null     object
#  4   deaths           36 non-null     int64
#  5   dose1            36 non-null     int64
#  6   dose2            36 non-null     int64
#  7   dose3            36 non-null     int64
#  8   precaution_dose  36 non-null     int64
#  9   total_doses      36 non-null     int64
#  10  population       36 non-null     int64
#  11  doses            36 non-null     int64
# dtypes: int64(10), object(2)
# memory usage: 3.7+ KB

# %% [markdown]
# #### The data type of the passive variable is changed from integer to the object
